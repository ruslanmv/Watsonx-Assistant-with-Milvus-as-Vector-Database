# %% [markdown]
# # WatsonX BackEnd Pipeline

# %% [markdown]
# ## Preparations

# %% [markdown]
# First we need to install dependencies such as towhee, towhee.models and gradio.

# %%
# !python3 -m pip install -q towhee towhee.models gradio datasets ipywidgets

# %% [markdown]
# ### Prepare the Data

# %%
from datasets import load_dataset
from IPython.display import clear_output
dataset = load_dataset("ruslanmv/ai-medical-chatbot")
clear_output()

# %% [markdown]
# **dataset**: a file containing question and the answer.
#
# Let's take a quick look:

# %%
column_names = dataset["train"].column_names
print(column_names)
# Out:
# ['Description', 'Patient', 'Doctor']

# %%
train_data = dataset["train"]
for i in range(1):
    print(train_data[i])
# Out:
# {'Description': 'Q. What does abutment of the nerve root mean?', 'Patient': 'Hi doctor,I am just wondering what is abutting and abutment of the nerve root means in a back issue. Please explain. What treatment is required for\xa0annular bulging and tear?', 'Doctor': 'Hi. I have gone through your query with diligence and would like you to know that I am here to help you. For further information consult a neurologist online -->'}

# %% [markdown]
# For this demo let us choose the first 5000 dialogues

# %%
import pandas as pd
df = pd.DataFrame(train_data[:5000])

# %%
df.head()
# Out:
#                                          Description  \
# 0      Q. What does abutment of the nerve root mean?
# 1  Q. What should I do to reduce my weight gained...
# 2  Q. I have started to get lots of acne on my fa...
# 3  Q. Why do I have uncomfortable feeling between...
# 4  Q. My symptoms after intercourse threatns me e...
#
#                                              Patient  \
# 0  Hi doctor,I am just wondering what is abutting...
# 1  Hi doctor, I am a 22-year-old female who was d...
# 2  Hi doctor! I used to have clear skin but since...
# 3  Hello doctor,I am having an uncomfortable feel...
# 4  Hello doctor,Before two years had sex with a c...
#
#                                               Doctor
# 0  Hi. I have gone through your query with dilige...
# 1  Hi. You have really done well with the hypothy...
# 2  Hi there Acne has multifactorial etiology. Onl...
# 3  Hello. The popping and discomfort what you fel...
# 4  Hello. The HIV test uses a finger prick blood ...

# %% [markdown]
# For the development of the model, let just consider the patient and doctor

# %%
#df = df[["Patient", "Doctor"]].rename(columns={"Patient": "question", "Doctor": "answer"})
df = df[["Description", "Doctor"]].rename(columns={"Description": "question", "Doctor": "answer"})

# %%
# Add the 'ID' column as the first column
df.insert(0, 'id', df.index)
# Reset the index and drop the previous index column
df = df.reset_index(drop=True)

# %%
import re
# Clean the 'question' and 'answer' columns
df['question'] = df['question'].apply(lambda x: re.sub(r'\s+', ' ', x.strip()))
df['answer'] = df['answer'].apply(lambda x: re.sub(r'\s+', ' ', x.strip()))
df['question'] = df['question'].str.replace('^Q.', '', regex=True)
# Assuming your DataFrame is named df
max_length = 500  # Due to our enbeeding model does not allow long strings
df['question'] = df['question'].str.slice(0, max_length)

# %%
df.head()
# Out:
#    id                                           question  \
# 0   0         What does abutment of the nerve root mean?
# 1   1   What should I do to reduce my weight gained d...
# 2   2   I have started to get lots of acne on my face...
# 3   3   Why do I have uncomfortable feeling between t...
# 4   4   My symptoms after intercourse threatns me eve...
#
#                                               answer
# 0  Hi. I have gone through your query with dilige...
# 1  Hi. You have really done well with the hypothy...
# 2  Hi there Acne has multifactorial etiology. Onl...
# 3  Hello. The popping and discomfort what you fel...
# 4  Hello. The HIV test uses a finger prick blood ...

# %% [markdown]
# To use the dataset to get answers, let's first define the dictionary:
#
# - `id_answer`: a dictionary of id and corresponding answer

# %%
id_answer = df.set_index('id')['answer'].to_dict()

# %% [markdown]
# ### Create Milvus Collection

# %% [markdown]
# Before getting started, please make sure that you have started a [Milvus service](https://milvus.io/docs/install_standalone-docker.md). This notebook uses [milvus 2.2.10](https://milvus.io/docs/v2.2.x/install_standalone-docker.md) and [pymilvus 2.2.11](https://milvus.io/docs/release_notes.md#2210).

# %%
# !python3 -m pip install -q pymilvus==2.2.11 python-dotenv

# %% [markdown]
# Next to define the function `create_milvus_collection` to create collection in Milvus that uses the [L2 distance metric](https://milvus.io/docs/metric.md#Euclidean-distance-L2) and an [IVF_FLAT index](https://milvus.io/docs/index.md#IVF_FLAT).

# %% [markdown]
# ### Setup Remote Server
# Here we should define the variable `REMOTE_SERVER` just created [here](https://github.com/ruslanmv/Watsonx-Assistant-with-Milvus-as-Vector-Database/blob/master/README.md)

# %%
LOCAL_SERVER='127.0.0.1'
from dotenv import load_dotenv
import os
load_dotenv()
host_milvus = os.environ.get("REMOTE_SERVER", LOCAL_SERVER)

# %%
from pymilvus import connections, FieldSchema, CollectionSchema, DataType, Collection, utility
connections.connect(host=host_milvus, port='19530')

# %%
collection_name='qa_medical_big'
def create_milvus_collection(collection_name, dim):
    if utility.has_collection(collection_name):
        utility.drop_collection(collection_name)

    fields = [
    FieldSchema(name='id', dtype=DataType.INT64, descrition='ids', max_length=500, is_primary=True, auto_id=False),
    FieldSchema(name='embedding', dtype=DataType.FLOAT_VECTOR, descrition='embedding vectors', dim=dim)
    ]
    schema = CollectionSchema(fields=fields, description='reverse image search')
    collection = Collection(name=collection_name, schema=schema)

    # create IVF_FLAT index for collection.
    index_params = {
        'metric_type':'L2',
        'index_type':"IVF_FLAT",
        'params':{"nlist":2048}
    }
    collection.create_index(field_name="embedding", index_params=index_params)
    return collection
collection = create_milvus_collection(collection_name, 768)

# %% [markdown]
# ### Load question embedding into Milvus

# %% [markdown]
# We first generate embedding from question text with [dpr](https://towhee.io/text-embedding/dpr) operator and insert the embedding into Milvus. Towhee provides a [method-chaining style API](https://towhee.readthedocs.io/en/main/index.html) so that users can assemble a data processing pipeline with operators.

# %%
from IPython.display import clear_output

# %%
# %%time
from towhee import pipe, ops
import numpy as np
from towhee.datacollection import DataCollection
from IPython.display import clear_output
max_input_length = 500  # Maximum length allowed by the model
insert_pipe = (
    pipe.input('id', 'question', 'answer')
        .map('question', 'vec', lambda x: x[:max_input_length])  # Truncate the question if longer than 500 tokens
        .map('vec', 'vec', ops.text_embedding.dpr(model_name='facebook/dpr-ctx_encoder-single-nq-base'))
        .map('vec', 'vec', lambda x: x / np.linalg.norm(x, axis=0))
        .map(('id', 'vec'), 'insert_status', ops.ann_insert.milvus_client(host=host_milvus, port='19530', collection_name=collection_name))
        .output()
)
clear_output()
# Out:
# CPU times: user 797 ms, sys: 1.44 s, total: 2.23 s
# Wall time: 11.7 s

# %%
# %%time
# Assuming you have a DataFrame named df
# Iterate over each row in the DataFrame
for index, row in df.iterrows():
    question = row['question']
    # Truncate the question string if it exceeds the expected size for the model
    if len(question) > 500:
        row['question'] = question[:500]  # Truncate the question string if it exceeds 500 characters
    insert_pipe(*row)
# Clear the output
clear_output()
# Out:
# 2024-02-19 13:55:05,448 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 13:55:05,449 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 13:55:05,450 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 13:55:05,451 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 13:55:05,451 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 13:55:05,452 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 13:55:11,332 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 13:55:11,333 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 13:55:11,334 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 13:55:11,334 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 13:55:11,336 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 13:55:11,336 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 13:55:11,530 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 13:55:11,530 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 13:55:11,531 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 13:55:11,532 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 13:55:11,532 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 13:55:11,533 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 13:55:11,716 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 13:55:11,717 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 13:55:11,717 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 13:55:11,717 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 13:55:11,717 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 13:55:11,718 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 13:55:11,890 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 13:55:11,891 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 13:55:11,891 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 13:55:11,891 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 13:55:11,891 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 13:55:11,891 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 13:55:12,061 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 13:55:12,061 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 13:55:12,061 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 13:55:12,062 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 13:55:12,062 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 13:55:12,063 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 13:55:12,241 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 13:55:12,241 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 13:55:12,241 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 13:55:12,241 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 13:55:12,241 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 13:55:12,241 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 13:55:12,426 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 13:55:12,426 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 13:55:12,426 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 13:55:12,427 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 13:55:12,427 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 13:55:12,427 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 13:55:12,605 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 13:55:12,605 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 13:55:12,605 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 13:55:12,606 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 13:55:12,606 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 13:55:12,606 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 13:55:12,780 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 13:55:12,780 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 13:55:12,780 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 13:55:12,780 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 13:55:12,781 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 13:55:12,781 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 13:55:12,971 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 13:55:12,971 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 13:55:12,971 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 13:55:12,971 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 13:55:12,971 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 13:55:12,971 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 13:55:13,136 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 13:55:13,136 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 13:55:13,136 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 13:55:13,137 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 13:55:13,137 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 13:55:13,138 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 13:55:13,299 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 13:55:13,300 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 13:55:13,300 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 13:55:13,300 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 13:55:13,300 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 13:55:13,300 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 13:55:13,467 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 13:55:13,467 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 13:55:13,467 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 13:55:13,467 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 13:55:13,468 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 13:55:13,468 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 13:55:13,631 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 13:55:13,632 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 13:55:13,632 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 13:55:13,633 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 13:55:13,633 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 13:55:13,633 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 13:55:13,804 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 13:55:13,804 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 13:55:13,804 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 13:55:13,805 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 13:55:13,805 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 13:55:13,805 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 13:55:13,980 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 13:55:13,981 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 13:55:13,980 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 13:55:13,982 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 13:55:13,982 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 13:55:13,982 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 13:55:14,155 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 13:55:14,155 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 13:55:14,155 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 13:55:14,155 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 13:55:14,156 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 13:55:14,156 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 13:55:14,317 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 13:55:14,317 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 13:55:14,318 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 13:55:14,318 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 13:55:14,318 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 13:55:14,318 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 13:55:14,494 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 13:55:14,494 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 13:55:14,494 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 13:55:14,495 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 13:55:14,495 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 13:55:14,495 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 13:55:14,667 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 13:55:14,667 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 13:55:14,667 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 13:55:14,667 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 13:55:14,667 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 13:55:14,668 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 13:55:14,844 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 13:55:14,844 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 13:55:14,844 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 13:55:14,844 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 13:55:14,844 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 13:55:14,845 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 13:55:15,012 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 13:55:15,012 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 13:55:15,012 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 13:55:15,013 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 13:55:15,013 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 13:55:15,013 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 13:55:15,202 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 13:55:15,203 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 13:55:15,203 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 13:55:15,203 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 13:55:15,203 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 13:55:15,204 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 13:55:15,381 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 13:55:15,381 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 13:55:15,381 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 13:55:15,381 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 13:55:15,381 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 13:55:15,381 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 13:55:15,549 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 13:55:15,549 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 13:55:15,550 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 13:55:15,550 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 13:55:15,550 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 13:55:15,550 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 13:55:15,719 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 13:55:15,719 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 13:55:15,719 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 13:55:15,720 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 13:55:15,720 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 13:55:15,720 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 13:55:15,911 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 13:55:15,911 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 13:55:15,911 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 13:55:15,912 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 13:55:15,912 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 13:55:15,912 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 13:55:16,100 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 13:55:16,100 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 13:55:16,100 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 13:55:16,101 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 13:55:16,101 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 13:55:16,101 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 13:55:16,272 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 13:55:16,273 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 13:55:16,273 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 13:55:16,273 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 13:55:16,273 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 13:55:16,273 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 13:55:16,445 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 13:55:16,446 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 13:55
- 140727154312768 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 14:09:07,381 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 14:09:07,381 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 14:09:07,381 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 14:09:07,382 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 14:09:07,382 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 14:09:07,382 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 14:09:07,547 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 14:09:07,547 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 14:09:07,547 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 14:09:07,548 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 14:09:07,548 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 14:09:07,548 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 14:09:07,716 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 14:09:07,717 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 14:09:07,717 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 14:09:07,717 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 14:09:07,717 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 14:09:07,717 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 14:09:07,894 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 14:09:07,894 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 14:09:07,894 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 14:09:07,894 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 14:09:07,895 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 14:09:07,895 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 14:09:08,060 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 14:09:08,061 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 14:09:08,061 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 14:09:08,061 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 14:09:08,062 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 14:09:08,062 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 14:09:08,241 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 14:09:08,241 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 14:09:08,241 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 14:09:08,241 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 14:09:08,241 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 14:09:08,241 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 14:09:08,420 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 14:09:08,420 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 14:09:08,420 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 14:09:08,421 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 14:09:08,421 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 14:09:08,421 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 14:09:08,594 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 14:09:08,595 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-lambda-0
# 2024-02-19 14:09:08,595 - 140727171221056 - node.py-node:167 - INFO: Begin to run Node-text-embedding/dpr-1
# 2024-02-19 14:09:08,595 - 140727030187584 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2024-02-19 14:09:08,596 - 140727188129344 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-3
# 2024-02-19 14:09:08,596 - 140727179675200 - node.py-node:167 - INFO: Begin to run Node-_output
# 2024-02-19 14:09:08,769 - 140727154312768 - node.py-node:167 - INFO: Begin to run Node-_input
# 2024-02-19 14:09:08,769 - 140727162766912 - node.py-node:167 - INFO: Begin to run Node-lambda-0

# %%
# Iterate over each row in the DataFrame
#for index, row in df.iterrows():
#    insert_pipe(*row)

# %%
print('Total number of inserted data is {}.'.format(collection.num_entities))

# %% [markdown]
# ### Ask Question with Milvus and Towhee

# %% [markdown]
# Now that embedding for question dataset have been inserted into Milvus, we can ask question with Milvus and Towhee. Again, we use Towhee to load the input question, compute a embedding, and use it as a query in Milvus. Because Milvus only outputs IDs and distance values, we provide the `id_answers` dictionary to get the answers based on IDs and display.

# %%
from towhee import pipe, ops
import numpy as np
from towhee.datacollection import DataCollection
from IPython.display import clear_output
# Define the maximum input length for the question
max_input_length = 512

# %%
# %%time
# Load the collection
collection.load()
# Create the combined pipe for question encoding and answer retrieval
combined_pipe = (
    pipe.input('question')
        .map('question', 'vec', lambda x: x[:max_input_length])  # Truncate the question if longer than 512 tokens
        .map('vec', 'vec', ops.text_embedding.dpr(model_name='facebook/dpr-ctx_encoder-single-nq-base'))
        .map('vec', 'vec', lambda x: x / np.linalg.norm(x, axis=0))
        .map('vec', 'res', ops.ann_search.milvus_client(host=host_milvus, port='19530', collection_name=collection_name, limit=1))
        .map('res', 'answer', lambda x: [id_answer[int(i[0])] for i in x])
        .output('question', 'answer')
)
clear_output()

# %%
# %%time
# Perform the encoding and retrieval for a specific question
ans = combined_pipe('What does abutment of the nerve root mean?')
ans = DataCollection(ans)

# %%
ans.show()

# %% [markdown]
# Then we can get the answer about 'What does abutment of the nerve root mean?'.

# %%
ans[0]['answer']
